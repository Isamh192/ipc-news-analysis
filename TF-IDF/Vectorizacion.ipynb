# %% [markdown]
# ## Importar librerias.

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os.path
import sys
import pickle

# %% [markdown]
# * Leemos el corpus y lo pasamos a un dataframe y lo almacenamos.

# %%
corpus = pd.read_csv(r"../filtered_dataset\noticias_expansion_filtradas.csv")

# %%
corpus
# Out:
#                                                titulo  \
# 0   Emilio Romano asume como presidente de la ABM;...
# 1   #Crónica | Una fiesta bancaria entre laberinto...
# 2   Banxico pide a la banca creatividad para dar s...
# 3   Gobierno y bancos acuerdan aumentar 3.5% anual...
# 4   Citigroup enfrenta demanda de 1,000 mmd en cas...
# 5   Banqueros ven 'inicios' de desaceleración del ...
# 6   Inflación en abril se ubicó en 3.93% y superó ...
# 7   La Fed mantiene las tasas y menciona riesgo de...
# 8   Banxico prevé nuevos recortes a la tasa si la ...
# 9   Banxico aún tiene margen para bajar tasa clave...
# 10  La banca endurece controles antiterrorismo con...
# 11  Los aranceles y las compras por internet acele...
# 12  Los Cetes a 28 días registran tercera semana c...
# 13  La inversión extranjera gira de la manufactura...
# 14  EU: Aranceles, recortes fiscales y desregulaci...
# 15  Trump anuncia nuevos aranceles, ahora contra l...
# 16  Habrá más inflación y menor crecimiento para 2...
# 17  Recortes y más recaudación por impuestos sella...
# 18  Hacienda descarta alteración de estimaciones p...
# 19  México evita recesión técnica al crecer 0.2% e...
# 20  Banamex: Remanentes "simbólicos" de Banxico ra...
# 21  Trump firma decreto para aliviar la carga de l...
# 22  Los Cetes a 28 días despiden abril con su rend...
# 23    BBVA México estima crecimiento negativo en 2025
# 24  Banco Mundial: Precios de materias primas caer...
#
#                                        palabras_clave     fuente  \
# 0   presidente banco director asociación protesta ...  expansion
# 1        deuda humo blanco haciendo banxico optimismo  expansion
# 2      financiero banxico sistema banca banco llamado  expansion
# 3            pyme periodo presidenta plan claudio abm  expansion
# 4   citigroup pese oceanografía dólares petrolero ...  expansion
# 5   crédito economía desaceleración empresa person...  expansion
# 6      producto precio genérico alza mercado jitomate  expansion
# 7     desempleo reserva economía sólido ritmo general  expansion
# 8   estable entorno gobernadora incierto central b...  expansion
# 9   margen tasa manteniéndola referencia real terr...  expansion
# 10      abogado hsbc tecnología cierre equipo banorte  expansion
# 11  hacienda gravamen recaudación impuesto interne...  expansion
# 12                    tasa cet corto méxico plazo mes  expansion
# 13  manufactura comercio inversión frente trimestr...  expansion
# 14  recorte desregulación congreso trump republica...  expansion
# 15  hollywood tendencia presidente estudio extranj...  expansion
# 16  crecimiento inflación débil banxico encuesta e...  expansion
# 17  sheinbaum presupuesto octubre ajuste año trime...  expansion
# 18    remanent peso millón hacienda costo información  expansion
# 19  sector pib impulsado trimestre agropecuario té...  expansion
# 20  remanent banco independencia millón gobierno p...  expansion
# 21          sector detroit anuncio warren trump mitin  expansion
# 22       mes rendimiento expectativa tasa interés cet  expansion
# 23    crecimiento negativo banco dato méxico recesión  expansion
# 24         materia primo precio alto bendición tercio  expansion
#
#                                             contenido   seccion  \
# 0   El director de Bank of America rindió protesta...  economia
# 1   La ABM presumió que el sistema financiero es s...  economia
# 2   La gobernadora del Banco de México (Banxico), ...  economia
# 3   La presidenta Claudia Sheinbaum y la ABM suscr...  economia
# 4   Los demandantes afirman que Citigroup adelantó...  economia
# 7   La Fed mantiene las tasas y menciona riesgo de...
# 8   Banxico prevé nuevos recortes a la tasa si la ...
# 9   Banxico aún tiene margen para bajar tasa clave...
# 10  La banca endurece controles antiterrorismo con...
# 11  Los aranceles y las compras por internet acele...
# 12  Los Cetes a 28 días registran tercera semana c...
# 13  La inversión extranjera gira de la manufactura...
# 14  EU: Aranceles, recortes fiscales y desregulaci...
# 15  Trump anuncia nuevos aranceles, ahora contra l...
# 16  Habrá más inflación y menor crecimiento para 2...
# 17  Recortes y más recaudación por impuestos sella...
# 18  Hacienda descarta alteración de estimaciones p...
# 19  México evita recesión técnica al crecer 0.2% e...
# 20  Banamex: Remanentes "simbólicos" de Banxico ra...
# 21  Trump firma decreto para aliviar la carga de l...
# 22  Los Cetes a 28 días despiden abril con su rend...
# 23  BBVA México estima crecimiento negativo en 202...
# 24  Banco Mundial: Precios de materias primas caer...
#
#                                            texto_comp  \
# 0   Emilio Romano asume como presidente de la ABM;...
# 1   #Crónica | Una fiesta bancaria entre laberinto...
# 2   Banxico pide a la banca creatividad para dar s...
# 3   Gobierno y bancos acuerdan aumentar 3.5% anual...
# 4   Citigroup enfrenta demanda de 1,000 mmd en cas...
# 5   Banqueros ven 'inicios' de desaceleración del ...
# 6   Inflación en abril se ubicó en 3.93% y superó ...
# 7   La Fed mantiene las tasas y menciona riesgo de...
# 8   Banxico prevé nuevos recortes a la tasa si la ...
# 9   Banxico aún tiene margen para bajar tasa clave...
# 10  La banca endurece controles antiterrorismo con...
# 11  Los aranceles y las compras por internet acele...
# 12  Los Cetes a 28 días registran tercera semana c...
# 13  La inversión extranjera gira de la manufactura...
# 14  EU: Aranceles, recortes fiscales y desregulaci...
# 15  Trump anuncia nuevos aranceles, ahora contra l...
# 16  Habrá más inflación y menor crecimiento para 2...
# 17  Recortes y más recaudación por impuestos sella...
# 18  Hacienda descarta alteración de estimaciones p...
# 19  México evita recesión técnica al crecer 0.2% e...
# 20  Banamex: Remanentes "simbólicos" de Banxico ra...
# 21  Trump firma decreto para aliviar la carga de l...
# 22  Los Cetes a 28 días despiden abril con su rend...
# 23  BBVA México estima crecimiento negativo en 202...
# 24  Banco Mundial: Precios de materias primas caer...
#
#                    coincidencias
# 0                            oma
# 1                        banxico
# 2                        banxico
# 3                 financiamiento
# 4                        demanda
# 5                 desaceleración
# 6   expectativas, inflación, oma
# 7           desempleo, inflación
# 8             banxico, inflación
# 9                        banxico
# 10                       banorte
# 11                     aranceles
# 12                         cetes
# 13                     inversión
# 14          aranceles, inversión
# 15                     aranceles
# 16            banxico, inflación
# 17                     impuestos
# 18                       banxico
# 19                      recesión
# 20                       banxico
# 21                     aranceles
# 22                         cetes
# 23                      recesión
# 24      materias primas, precios

# %% [markdown]
# ## Normalización de texto.

# %% [markdown]
# * Función que normaliza texto de un corpus.

# %%
import spacy as sp

# %%
def normalizador(corpus: pd.DataFrame, col_name: str, obj_nlp) -> pd.DataFrame:
    words_category = ["DET", "ADP", "CCONJ", "SCONJ","PRON"]
    obj_nlp = sp.load("es_core_news_sm")
    corpus.fillna('', inplace=True)
    
    list_col = corpus[col_name].tolist()
    list_final = []
    
    for i in range(len(list_col)):
        list_to_normal = list_col[i].lower() 
        doc = obj_nlp(list_to_normal)
        
        list_normal = []
        for token in doc:
            if token.pos_ not in words_category and token.is_alpha:
                list_normal.append(token.lemma_)
        
        text_norm = ' '.join(list_normal) 
        list_final.append(text_norm)
    
    corpus[col_name] = list_final 
    
    return corpus

# %% [markdown]
# ## Nuevos conjuntos de datos.

# %% [markdown]
# * Creamos tres nuevos conjunto de datos y estaran divididos de la siguiente manera:
#
#     * **Titulo**: Unicamente tendra la columna **titulo**.
#     * **Contenido**: Unicamente tendra la columna **contenido**.
#     * **Titulo + contenido**: Es la concatenación de las columnas **titulo y contenido**.

# %%
def new_sets(corpus: pd.DataFrame) -> tuple:
    corpus.fillna('',inplace=True)
     
    only_title = corpus[['titulo']].copy()
    only_summary = corpus[['palabras_clave']].copy()
    title_summary = pd.DataFrame(corpus['titulo'] + ' ' + corpus['palabras_clave'], columns=['titulo_contenido'])
    
    return only_title, only_summary, title_summary

# %%
nlp = sp.load("es_core_news_sm")

# %%
corpus = normalizador(corpus, col_name="titulo", obj_nlp=nlp)

# %%
df_1, df_2, df_3 = new_sets(corpus)
df_1.name = df_1.columns[0]
df_2.name = df_2.columns[0]
df_3.name = df_3.columns[0]

# %%
df_3
# Out:
#                                      titulo_contenido
# 0   emilio romano asumir presidente prometer más d...
# 1   crónico fiesta bancario laberinto humo blanco ...
# 2   banxico pedir banco creatividad dar solución f...
# 3   gobierno banco acordar aumentar anual financia...
# 4   citigroup enfrento demanda mmd caso fraude pet...
# 5   banquero ver inicio desaceleración crédito cré...
# 6   inflación abril ubicar superar expectativa mer...
# 7   fed mantener tasa mencionar riesgo mayor infla...
# 8   banxico prever nuevo recorte tasa inflación ma...
# 9   banxico aún tener margen bajar tasa clave aseg...
# 10  banca endurecer control antiterrorismo abogado...
# 11  arancel compra internet aceleran recaudación h...
# 12  cet día registrar tercero semana consecutivo b...
# 13  inversión extranjero gira manufactura comercio...
# 14  eu arancel recorte fiscal desregulación trump ...
# 15  trump anunciar nuevo arancel ahora película ex...
# 16  haber más inflación menor crecimiento factor e...
# 17  recorte más recaudación impuesto sellan primer...
# 18  hacienda descartar alteración estimación menos...
# 19  méxico evitar recesión técnico crecer primero ...
# 20  banamex remanent simbólico banxico ratificir a...
# 21  trump  firma decreto aliviar carga arancel sec...
# 22  cet día despedir abril rendimiento más bajo me...
# 23  bbva méxico estimar crecimiento negativo creci...
# 24  banco mundial precio materia primo caer nivel ...

# %% [markdown]
# ## Representación Vectorial.
#
# * Se hara una representación vectorial del corpus de las siguientes formas:
#     * **TF-IDF**.
#
# * Se usaran las siguientes caracteristicas:
#     * **Unigramas**.
#     * **Bigramas**.

# %% [markdown]
# * Función que guarda en un archivo **.pkl** los nombres de las caracteristicas y la matriz de la representación vectorial.

# %%
def doc_to_vect(corpus: pd.DataFrame, col_name: str, form: str, feature: str) -> tuple:
    
    output_dir = os.path.join("..", "embedding")
    os.makedirs(output_dir, exist_ok=True)
    file_name = os.path.join(output_dir, f'{form}_{feature}_{corpus.name}_train_vector.pkl')
    
    if os.path.exists(file_name):
        print(f'Ya existe {file_name}, cargando...')
        with open(file_name, 'rb') as vector_file:
            X, feature_names, rep = pickle.load(vector_file)
        return X, feature_names
    
    if form == 'TF-IDF' and feature == 'Unigrama':
        rep_vec = TfidfVectorizer(token_pattern= r'(?u)\w+|\w+\n|\.|\¿|\?')
        X = rep_vec.fit_transform(corpus[col_name])
        feature_names = rep_vec.get_feature_names_out()
    elif form == 'TF-IDF' and feature == 'Bigrama':
        rep_vec = TfidfVectorizer(token_pattern= r'(?u)\w+|\w+\n|\.|\¿|\?', ngram_range=(2,2))
        X = rep_vec.fit_transform(corpus[col_name])
        feature_names = rep_vec.get_feature_names_out()

    with open(file_name, 'wb') as vector_file:
        pickle.dump((X.toarray(), feature_names, rep_vec), vector_file)
    
    return X.toarray(), feature_names

# %%
forms = ['TF-IDF']
features = ['Bigrama', 'Unigrama']
dataframes = [df_1, df_2, df_3]

for dataframe in dataframes:
    for form in forms:
        for feature in features:
            X, names = doc_to_vect(dataframe, dataframe.name, form, feature)
# Out:
# Ya existe ..\embedding\TF-IDF_Bigrama_titulo_train_vector.pkl, cargando...
# Ya existe ..\embedding\TF-IDF_Unigrama_titulo_train_vector.pkl, cargando...
# Ya existe ..\embedding\TF-IDF_Bigrama_palabras_clave_train_vector.pkl, cargando...
# Ya existe ..\embedding\TF-IDF_Unigrama_palabras_clave_train_vector.pkl, cargando...
# Ya existe ..\embedding\TF-IDF_Bigrama_titulo_contenido_train_vector.pkl, cargando...
# Ya existe ..\embedding\TF-IDF_Unigrama_titulo_contenido_train_vector.pkl, cargando...

# %%
file_names = [

'TF-IDF_Bigrama_titulo_train_vector.pkl',
'TF-IDF_Unigrama_titulo_train_vector.pkl',
'TF-IDF_Bigrama_palabras_clave_train_vector.pkl',
'TF-IDF_Unigrama_palabras_clave_train_vector.pkl',
'TF-IDF_Bigrama_titulo_contenido_train_vector.pkl',
'TF-IDF_Unigrama_titulo_contenido_train_vector.pkl'
]

# %%
import pickle
import pandas as pd

file = r'..\embedding\TF-IDF_Bigrama_palabras_clave_train_vector.pkl'
with open(file, 'rb') as f:
    X, feature_names, vectorizer = pickle.load(f)

df_tfidf = pd.DataFrame(X, columns=feature_names)
df_tfidf
# Out:
#     abogado hsbc  agropecuario técnico  ajuste año  alto bendición  \
# 0       0.000000              0.000000    0.000000        0.000000
# 1       0.000000              0.000000    0.000000        0.000000
# 2       0.000000              0.000000    0.000000        0.000000
# 3       0.000000              0.000000    0.000000        0.000000
# 4       0.000000              0.000000    0.000000        0.000000
# 5       0.000000              0.000000    0.000000        0.000000
# 6       0.000000              0.000000    0.000000        0.000000
# 7       0.000000              0.000000    0.000000        0.000000
# 8       0.000000              0.000000    0.000000        0.000000
# 9       0.000000              0.000000    0.000000        0.000000
# 10      0.447214              0.000000    0.000000        0.000000
# 11      0.000000              0.000000    0.000000        0.000000
# 12      0.000000              0.000000    0.000000        0.000000
# 13      0.000000              0.000000    0.000000        0.000000
# 14      0.000000              0.000000    0.000000        0.000000
# 15      0.000000              0.000000    0.000000        0.000000
# 16      0.000000              0.000000    0.000000        0.000000
# 17      0.000000              0.000000    0.447214        0.000000
# 18      0.000000              0.000000    0.000000        0.000000
# 19      0.000000              0.447214    0.000000        0.000000
# 20      0.000000              0.000000    0.000000        0.000000
# 21      0.000000              0.000000    0.000000        0.000000
# 1           0.000000     0.000000           0.000000      0.000000
# 2           0.000000     0.000000           0.000000      0.000000
# 3           0.000000     0.000000           0.000000      0.000000
# 4           0.000000     0.000000           0.000000      0.000000
# 5           0.000000     0.000000           0.000000      0.000000
# 6           0.000000     0.000000           0.000000      0.000000
# 7           0.000000     0.000000           0.000000      0.000000
# 8           0.000000     0.000000           0.000000      0.000000
# 9           0.000000     0.000000           0.000000      0.000000
# 10          0.000000     0.000000           0.000000      0.000000
# 11          0.000000     0.000000           0.000000      0.000000
# 12          0.000000     0.000000           0.000000      0.000000
# 13          0.447214     0.000000           0.000000      0.000000
# 14          0.000000     0.000000           0.447214      0.000000
# 15          0.000000     0.000000           0.000000      0.000000
# 16          0.000000     0.000000           0.000000      0.000000
# 17          0.000000     0.000000           0.000000      0.000000
# 18          0.000000     0.000000           0.000000      0.000000
# 19          0.000000     0.000000           0.000000      0.000000
# 20          0.000000     0.000000           0.000000      0.000000
# 21          0.000000     0.447214           0.000000      0.447214
# 22          0.000000     0.000000           0.000000      0.000000
# 23          0.000000     0.000000           0.000000      0.000000
# 24          0.000000     0.000000           0.000000      0.000000
#
# [25 rows x 125 columns]

# %%
import pickle
import pandas as pd

file = r'..\embedding\TF-IDF_Unigrama_palabras_clave_train_vector.pkl'
with open(file, 'rb') as f:
    X, feature_names, vectorizer = pickle.load(f)

df_tfidf = pd.DataFrame(X, columns=feature_names)
df_tfidf
# Out:
#          abm   abogado  agropecuario    ajuste      alto      alza   americo  \
# 0   0.000000  0.000000      0.000000  0.000000  0.000000  0.000000  0.435851
# 1   0.000000  0.000000      0.000000  0.000000  0.000000  0.000000  0.000000
# 2   0.000000  0.000000      0.000000  0.000000  0.000000  0.000000  0.000000
# 3   0.408248  0.000000      0.000000  0.000000  0.000000  0.000000  0.000000
# 4   0.000000  0.000000      0.000000  0.000000  0.000000  0.000000  0.000000
# 5   0.000000  0.000000      0.000000  0.000000  0.000000  0.000000  0.000000
# 6   0.000000  0.000000      0.000000  0.000000  0.000000  0.415749  0.000000
# 7   0.000000  0.000000      0.000000  0.000000  0.000000  0.000000  0.000000
# 8   0.000000  0.000000      0.000000  0.000000  0.000000  0.000000  0.000000
# 9   0.000000  0.000000      0.000000  0.000000  0.000000  0.000000  0.000000
# 10  0.000000  0.408248      0.000000  0.000000  0.000000  0.000000  0.000000
# 11  0.000000  0.000000      0.000000  0.000000  0.000000  0.000000  0.000000
# 12  0.000000  0.000000      0.000000  0.000000  0.000000  0.000000  0.000000
# 13  0.000000  0.000000      0.000000  0.000000  0.000000  0.000000  0.000000
# 14  0.000000  0.000000      0.000000  0.000000  0.000000  0.000000  0.000000
# 15  0.000000  0.000000      0.000000  0.000000  0.000000  0.000000  0.000000
# 16  0.000000  0.000000      0.000000  0.000000  0.000000  0.000000  0.000000
# 17  0.000000  0.000000      0.000000  0.420743  0.000000  0.000000  0.000000
# 18  0.000000  0.000000      0.000000  0.000000  0.000000  0.000000  0.000000
# 19  0.000000  0.000000      0.434459  0.000000  0.000000  0.000000  0.000000
# 20  0.000000  0.000000      0.000000  0.000000  0.000000  0.000000  0.000000
# 21  0.000000  0.000000      0.000000  0.000000  0.000000  0.000000  0.000000
# 22  0.000000  0.000000      0.000000  0.000000  0.000000  0.000000  0.000000
# 23  0.000000  0.000000      0.000000  0.000000  0.000000  0.000000  0.000000
# 24  0.000000  0.000000      0.000000  0.000000  0.415749  0.000000  0.000000
#
#      anuncio  asociación       año  ...      tasa  tecnología  tendencia  \
# 0   0.000000    0.435851  0.000000  ...  0.000000    0.000000   0.000000
# 1   0.000000    0.000000  0.000000  ...  0.000000    0.000000   0.000000
# 2   0.000000    0.000000  0.000000  ...  0.000000    0.000000   0.000000
# 3   0.000000    0.000000  0.000000  ...  0.000000    0.000000   0.000000
# 4   0.000000    0.000000  0.000000  ...  0.000000    0.000000   0.000000
# 5   0.000000    0.000000  0.000000  ...  0.000000    0.000000   0.000000
# 6   0.000000    0.000000  0.000000  ...  0.000000    0.000000   0.000000
# 7   0.000000    0.000000  0.000000  ...  0.000000    0.000000   0.000000
# 8   0.000000    0.000000  0.000000  ...  0.000000    0.000000   0.000000
# 9   0.000000    0.000000  0.000000  ...  0.338936    0.000000   0.000000
# 10  0.000000    0.000000  0.000000  ...  0.000000    0.408248   0.000000
# 11  0.000000    0.000000  0.000000  ...  0.000000    0.000000   0.000000
# 12  0.000000    0.000000  0.000000  ...  0.360068    0.000000   0.000000
# 13  0.000000    0.000000  0.000000  ...  0.000000    0.000000   0.000000
# 14  0.000000    0.000000  0.000000  ...  0.000000    0.000000   0.000000
# 15  0.000000    0.000000  0.000000  ...  0.000000    0.000000   0.415749
# 16  0.000000    0.000000  0.000000  ...  0.000000    0.000000   0.000000
# 17  0.000000    0.000000  0.420743  ...  0.000000    0.000000   0.000000
# 18  0.000000    0.000000  0.000000  ...  0.000000    0.000000   0.000000
# 19  0.000000    0.000000  0.000000  ...  0.000000    0.000000   0.000000
# 20  0.000000    0.000000  0.000000  ...  0.000000    0.000000   0.000000
# 21  0.428967    0.000000  0.000000  ...  0.000000    0.000000   0.000000
# 22  0.000000    0.000000  0.000000  ...  0.352591    0.000000   0.000000
# 23  0.000000    0.000000  0.000000  ...  0.000000    0.000000   0.000000
# 24  0.000000    0.000000  0.000000  ...  0.000000    0.000000   0.000000
#
#       tercio  territorio  tributario  trimestre     trump   técnico    warren
# 0   0.000000    0.000000    0.000000   0.000000  0.000000  0.000000  0.000000
# 1   0.000000    0.000000    0.000000   0.000000  0.000000  0.000000  0.000000
# 2   0.000000    0.000000    0.000000   0.000000  0.000000  0.000000  0.000000
# 3   0.000000    0.000000    0.000000   0.000000  0.000000  0.000000  0.000000
# 4   0.000000    0.000000    0.000000   0.000000  0.000000  0.000000  0.000000
# 5   0.000000    0.000000    0.000000   0.000000  0.000000  0.000000  0.000000
# 6   0.000000    0.000000    0.000000   0.000000  0.000000  0.000000  0.000000
# 7   0.000000    0.000000    0.000000   0.000000  0.000000  0.000000  0.000000
# 8   0.000000    0.000000    0.000000   0.000000  0.000000  0.000000  0.000000
# 9   0.000000    0.420743    0.000000   0.000000  0.000000  0.000000  0.000000
# 10  0.000000    0.000000    0.000000   0.000000  0.000000  0.000000  0.000000
# 11  0.000000    0.000000    0.000000   0.000000  0.000000  0.000000  0.000000
# 12  0.000000    0.000000    0.000000   0.000000  0.000000  0.000000  0.000000
# 13  0.000000    0.000000    0.000000   0.349986  0.000000  0.000000  0.000000
# 14  0.000000    0.000000    0.415749   0.000000  0.368463  0.000000  0.000000
# 15  0.000000    0.000000    0.000000   0.000000  0.000000  0.000000  0.000000
# 16  0.000000    0.000000    0.000000   0.000000  0.000000  0.000000  0.000000
# 17  0.000000    0.000000    0.000000   0.338936  0.000000  0.000000  0.000000
# 18  0.000000    0.000000    0.000000   0.000000  0.000000  0.000000  0.000000
# 19  0.000000    0.000000    0.000000   0.349986  0.000000  0.434459  0.000000
# 20  0.000000    0.000000    0.000000   0.000000  0.000000  0.000000  0.000000
# 21  0.000000    0.000000    0.000000   0.000000  0.380178  0.000000  0.428967
# 22  0.000000    0.000000    0.000000   0.000000  0.000000  0.000000  0.000000
# 23  0.000000    0.000000    0.000000   0.000000  0.000000  0.000000  0.000000
# 24  0.415749    0.000000    0.000000   0.000000  0.000000  0.000000  0.000000
#
# [25 rows x 125 columns]
